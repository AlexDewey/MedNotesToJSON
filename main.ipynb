# %%
from JSONcreate import get_json
from JSONevalute import compare_json
import pandas as pd
import json

# %%
# Get data
data = pd.read_csv('./data/train.csv')


for index in range(0, 10):
    row = data.iloc[index]
    json_string = get_json('gpt-oss', row['Note'])

    print(ground_truth_obj)
    print(generated_obj)

    ground_truth_obj = json.loads(row['json'])
    generated_obj = json.loads(json_string)

    similarity = compare_json(ground_truth_obj, generated_obj)
    print(f"Similarity with ground truth: {similarity:.2f}%\n")
# Out:
# Similarity with ground truth: 0.86%
#
# Similarity with ground truth: 0.91%
#
# Similarity with ground truth: 1.00%
#
# Similarity with ground truth: 1.00%
#
# Similarity with ground truth: 0.95%
#
# Similarity with ground truth: 0.64%
#
# Similarity with ground truth: 0.98%
#
# Similarity with ground truth: 1.00%
#
# Similarity with ground truth: 0.86%
#
# Similarity with ground truth: 0.94%

# %%
# Get data
data = pd.read_csv('./data/train.csv')


row = data.iloc[5]
json_string = get_json('gpt-oss', row['Note'])

print(ground_truth_obj)
print(generated_obj)

ground_truth_obj = json.loads(row['json'])
generated_obj = json.loads(json_string)

similarity = compare_json(ground_truth_obj, generated_obj)
print(f"Similarity with ground truth: {similarity:.2f}%\n")
