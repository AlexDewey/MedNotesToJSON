# %%
from JSONcreate import get_json_full, get_json_segment
from JSONevalute import compare_json
import pandas as pd
import json

# %%
# Get data
data = pd.read_csv('./data/train.csv')

num_samples = 10

results = 0
semi_results = 0
for index in range(0, num_samples):
    row = data.iloc[index]
    json_string = get_json_full(model='gpt-oss', notes=row['Note']) #gpt-oss #thewindmom/llama3-med42-8b

    ground_truth_obj = json.loads(row['json'])
    generated_obj = json.loads(json_string)

    print(ground_truth_obj)
    print(generated_obj)

    similarity = compare_json(ground_truth_obj, generated_obj)
    results += similarity
    print(f"Similarity with ground truth: {similarity:.2f}%\n")

print(f"Average similarity over {num_samples} samples: {results / num_samples:.5f}%")
# Out:
# {'patient_info': {'age': 41, 'gender': 'Male'}, 'visit_motivation': 'Anemia', 'symptoms': ['fever', 'fatigue', 'difficulty_breathing', 'vomiting', 'dizziness', 'blurred_vision', 'wheezing', 'pale_skin'], 'vital_signs': {'heart_rate': {'value': 114, 'unit': 'bpm'}, 'oxygen_saturation': {'value': 98.4, 'unit': '%'}, 'cholesterol_level': {'value': 132.8, 'unit': 'mg/dL'}, 'glucose_level': {'value': 110.6, 'unit': 'mg/dL'}}}
# {'patient_info': {'age': 41, 'gender': 'Male'}, 'visit_motivation': 'Anemia', 'symptoms': ['fever', 'fatigue', 'difficulty_breathing', 'vomiting', 'dizziness', 'blurred_vision', 'wheezing'], 'vital_signs': {'heart_rate': {'value': 114, 'unit': 'bpm'}, 'oxygen_saturation': {'value': 98.4, 'unit': '%'}, 'glucose_level': {'value': 110.6, 'unit': 'mg/dL'}, 'cholesterol_level': {'value': 132.8, 'unit': 'mg/dL'}}}
# Similarity with ground truth: 0.98%
#
# {'patient_info': {'age': 56, 'gender': 'Male'}, 'visit_motivation': 'Allergies', 'symptoms': ['runny_nose', 'sneezing', 'itchy_eyes', 'blurred_vision', 'wheezing'], 'vital_signs': {'temperature': {'value': 36.6, 'unit': '°C'}, 'respiratory_rate': {'value': 13, 'unit': 'breaths/min'}, 'glucose_level': {'value': 99.0, 'unit': 'mg/dL'}}}
# {'patient_info': {'age': 56, 'gender': 'Male'}, 'visit_motivation': 'Allergies', 'symptoms': ['runny_nose', 'sneezing', 'itchy_eyes', 'blurred_vision', 'wheezing'], 'vital_signs': {'temperature': {'value': 36.6, 'unit': '°C'}, 'respiratory_rate': {'value': 13, 'unit': 'breaths/min'}, 'glucose_level': {'value': 99, 'unit': 'mg/dL'}}}
# Similarity with ground truth: 1.00%
#
# {'patient_info': {'age': 73, 'gender': 'Female'}, 'visit_motivation': 'Diabetes (Type 2)', 'symptoms': ['fever', 'headache', 'difficulty_breathing', 'chest_pain', 'vomiting', 'sneezing', 'loss_of_taste_smell', 'increased_thirst', 'blurred_vision', 'wheezing', 'night_sweats', 'painful_urination', 'pale_skin', 'difficulty_concentrating'], 'vital_signs': {'heart_rate': {'value': 92, 'unit': 'bpm'}, 'respiratory_rate': {'value': 18, 'unit': 'breaths/min'}, 'cholesterol_level': {'value': 173.0, 'unit': 'mg/dL'}, 'glucose_level': {'value': 224.8, 'unit': 'mg/dL'}}}
# {'patient_info': {'age': 73, 'gender': 'Female'}, 'visit_motivation': 'Diabetes (Type 2)', 'symptoms': ['fever', 'headache', 'difficulty_breathing', 'chest_pain', 'vomiting', 'sneezing', 'loss_of_taste_smell', 'increased_thirst', 'blurred_vision', 'wheezing', 'night_sweats', 'painful_urination', 'pale_skin', 'difficulty_concentrating'], 'vital_signs': {'heart_rate': {'value': 92, 'unit': 'bpm'}, 'respiratory_rate': {'value': 18, 'unit': 'breaths/min'}, 'cholesterol_level': {'value': 173.0, 'unit': 'mg/dL'}, 'glucose_level': {'value': 224.8, 'unit': 'mg/dL'}}}
# Similarity with ground truth: 1.00%
#
# {'patient_info': {'age': 32, 'gender': 'Female'}, 'visit_motivation': 'Allergies', 'symptoms': ['fatigue', 'abdominal_pain', 'runny_nose', 'rash', 'joint_pain', 'sneezing', 'night_sweats', 'weight_loss', 'facial_pain', 'heartburn', 'sadness', 'difficulty_concentrating'], 'vital_signs': {'blood_pressure': {'systolic': {'value': 97, 'unit': 'mmHg'}, 'diastolic': {'value': 79, 'unit': 'mmHg'}}, 'temperature': {'value': 36.9, 'unit': '°C'}, 'heart_rate': {'value': 70, 'unit': 'bpm'}, 'respiratory_rate': {'value': 19, 'unit': 'breaths/min'}, 'oxygen_saturation': {'value': 98.2, 'unit': '%'}, 'glucose_level': {'value': 139.8, 'unit': 'mg/dL'}}}
# {'patient_info': {'age': 32, 'gender': 'Female'}, 'visit_motivation': 'Allergies', 'symptoms': ['fatigue', 'abdominal_pain', 'runny_nose', 'rash', 'joint_pain', 'sneezing', 'night_sweats', 'weight_loss', 'facial_pain', 'heartburn', 'sadness', 'difficulty_concentrating'], 'vital_signs': {'blood_pressure': {'systolic': {'value': 97, 'unit': 'mmHg'}, 'diastolic': {'value': 79, 'unit': 'mmHg'}}, 'temperature': {'value': 36.9, 'unit': '°C'}, 'heart_rate': {'value': 70, 'unit': 'bpm'}, 'respiratory_rate': {'value': 19, 'unit': 'breaths/min'}, 'oxygen_saturation': {'value': 98.2, 'unit': '%'}, 'glucose_level': {'value': 139.8, 'unit': 'mg/dL'}}}
# Similarity with ground truth: 1.00%
#
# {'patient_info': {'age': 51, 'gender': 'Male'}, 'visit_motivation': 'Tuberculosis (TB)', 'symptoms': ['fever', 'cough', 'nausea', 'joint_pain', 'sneezing', 'frequent_urination', 'blurred_vision', 'weight_loss', 'painful_urination', 'facial_pain', 'difficulty_concentrating'], 'vital_signs': {'blood_pressure': {'systolic': {'value': 92, 'unit': 'mmHg'}, 'diastolic': {'value': 74, 'unit': 'mmHg'}}, 'respiratory_rate': {'value': 19, 'unit': 'breaths/min'}, 'cholesterol_level': {'value': 125.7, 'unit': 'mg/dL'}, 'glucose_level': {'value': 70.7, 'unit': 'mg/dL'}}}
# {'patient_info': {'age': 51, 'gender': 'Male'}, 'visit_motivation': 'Tuberculosis (TB)', 'symptoms': ['fever', 'cough', 'nausea', 'joint_pain', 'sneezing', 'frequent_urination', 'blurred_vision', 'weight_loss', 'painful_urination', 'facial_pain', 'difficulty_concentrating', 'night_sweats', 'wheezing', 'fatigue'], 'vital_signs': {'blood_pressure': {'systolic': {'value': 92, 'unit': 'mmHg'}, 'diastolic': {'value': 74, 'unit': 'mmHg'}}, 'respiratory_rate': {'value': 19, 'unit': 'breaths/min'}, 'glucose_level': {'value': 70.7, 'unit': 'mg/dL'}, 'cholesterol_level': {'value': 125.7, 'unit': 'mg/dL'}}}
# Similarity with ground truth: 0.96%

# %%
from LLMAPIs import get_response
import pandas as pd

data = pd.read_csv('./data/train.csv')
row = data.iloc[2]

symptoms = get_response('gpt-oss',f"""
    You are a strict information extraction system.

    Extract only the explicitly mentioned symptoms from the medical note below.
    Do NOT infer or guess symptoms.

    Return ONLY valid JSON (no text before or after).

    Schema:
    {{ "symptoms": [<list of mentioned symptoms>] }}

    Possible symptoms:
    ["abdominal_pain", "anxiety", "blurred_vision", "chest_pain", "cough", "diarrhea", 
    "difficulty_breathing", "difficulty_concentrating", "dizziness", "dry_skin", "ear_pain", 
    "facial_pain", "fatigue", "fever", "frequent_urination", "headache", "heartburn", 
    "increased_thirst", "itchy_eyes", "joint_pain", "loss_of_taste_smell", "nausea", 
    "night_sweats", "painful_urination", "pale_skin", "rash", "restlessness", "runny_nose", 
    "sadness", "sneezing", "sore_throat", "swollen_lymph_nodes", "vomiting", "weight_loss", "wheezing"]

    ---
    Medical Note:
    {row['json']}
    """)
